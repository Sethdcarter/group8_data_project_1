# %%
import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Record Date Agency Bureau Indicator                           Agency Name  \
# 0  2024-06-30                  Agency  Agency for International Development
# 1  2024-06-30                  Bureau  Agency for International Development
# 2  2024-06-30                  Agency  American Battle Monuments Commission
# 3  2024-06-30                  Bureau  American Battle Monuments Commission
# 4  2024-06-30                  Agency          Armed Forces Retirement Home
#
#                             Bureau Name  Total Eligible Debt Amount  \
# 0                                   NaN                  28276178.0
# 1  Agency for International Development                  28276178.0
# 2                                   NaN                         0.0
# 3  American Battle Monuments Commission                         0.0
# 4                                   NaN                    108119.0
#
#    Total Eligible Debt Count  Eligible Debt Referred Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5973 entries, 0 to 5972
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Record Date                        5973 non-null   object
#  1   Agency Bureau Indicator            5973 non-null   object
#  2   Agency Name                        5973 non-null   object
#  3   Bureau Name                        4576 non-null   object
#  4   Total Eligible Debt Amount         5972 non-null   float64
#  5   Total Eligible Debt Count          5972 non-null   float64
#  6   Eligible Debt Referred Amount      5972 non-null   float64
#  7   Eligible Debt Referred Count       5972 non-null   float64
#  8   Eligible Debt Not Referred Amount  5972 non-null   float64
#  9   Eligible Debt Not Referred Count   5972 non-null   float64
#  10  Compliance Rate Amount             5972 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Total Eligible Debt Amount  Total Eligible Debt Count  \
# count                5.972000e+03               5.972000e+03
# mean                 1.186942e+09               2.162985e+05
# std                  1.121473e+10               1.969257e+06
# min                  0.000000e+00               0.000000e+00
# 25%                  0.000000e+00               0.000000e+00
# 50%                  4.645000e+04               7.000000e+00
# 75%                  8.458501e+06               4.285000e+02
# max                  1.746551e+11               2.934816e+07
#
#        Eligible Debt Referred Amount  Eligible Debt Referred Count  \
# count                   5.972000e+03                  5.972000e+03
# mean                    1.124025e+09                  1.936343e+05
# std                     1.072637e+10                  1.868531e+06
# min                     0.000000e+00                  0.000000e+00
# 25%                     0.000000e+00                  0.000000e+00
# ...

# %%
df.isnull().sum()
# Out:
# Record Date                             0
# Agency Bureau Indicator                 0
# Agency Name                             0
# Bureau Name                          1397
# Total Eligible Debt Amount              1
# Total Eligible Debt Count               1
# Eligible Debt Referred Amount           1
# Eligible Debt Referred Count            1
# Eligible Debt Not Referred Amount       1
# Eligible Debt Not Referred Count        1
# Compliance Rate Amount                  1
# Compliance Rate Count                   1
# CFO Agency Indicator                 4576
# Fiscal Year                             0
# Fiscal Quarter Number                   0
# Calendar Year                           0
# Calendar Quarter Number                 0
# Calendar Month Number                   0
# Calendar Day Number                     0
# dtype: int64

# %%
df["Fiscal Year"].value_counts()
# Out:
# Fiscal Year
# 2022    1200
# 2021    1197
# 2023    1194
# 2020    1190
# 2024     897
# 2019     295
# Name: count, dtype: int64

# %%
fy=df.groupby("Fiscal Year")["Total Eligible Debt Amount"].mean()

# %%
fy.plot(kind="bar", figsize=(10,6),color='skyblue')
plt.show()

# %%
plt.show()

# %%
plt.xlabel("United States Median House Price")
plt.ylabel("Average Eligible Debt Amount")
plt.title("Average Eligible Debt Amount by Fiscal Year")
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
fy_debt=df.groupby("Fiscal Year")["Total Eligible Debt Amount"].mean()
fy_growth=df.groupby("Fiscal Year")["Compliance Rate Amount"].mean()
